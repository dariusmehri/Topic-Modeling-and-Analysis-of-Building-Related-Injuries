# %% [markdown]
# # Part 1: Read Data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("S...Incident All.CSV")
df = df[["Incident date (MM/DD/YYYY)", "Initial Detail of Accident", "Fatality", "Injury"]]

# %%
print len(df)
df
# Out:
# 5710
#             Date                                              Notes  Fatality  \
# 4     2003-09-18  four alarm fire extensively damage first floor...       0.0
# 5     2003-09-21  dob violation 092103cnetz02  control 198300 is...       0.0
# 6     2003-09-30  terrocotta facing peeled frame from bulthead p...       0.0
# 7     2003-10-03  a 36 year old female tripped and fell against ...       0.0
# 8     2003-10-03       male injured his leg when elevator made stop       0.0
# 10    2003-10-09  two male workers were doing finishing floor wi...       0.0
# 11    2003-10-10  4th floor fright ele view window missing from ...       1.0
# 13    2003-10-12  a women walking down non moving escalator step...       0.0
# 16    2003-10-15  an adult female lost her balance on moving esc...       0.0
# 17    2003-10-15  male trapped in a elevator cab reported his ba...       0.0
# 19    2003-10-17  worker baska zbigniew 43 718 272 9331 fell fro...       0.0
# ...

# %% [markdown]
# # Part 1b: Prepare Data Before Analysis

# %%
df = df.rename(columns={'Initial Detail of Accident': 'Notes', 'Incident date (MM/DD/YYYY)': 'Date'})

df["Notes"] = df["Notes"].astype(str)
df["Notes"] = df["Notes"].map(str.lower)
df['Notes'] = df['Notes'].str.replace('.',' ')
df['Notes'] = df['Notes'].str.replace(',',' ')
df['Notes'] = df['Notes'].str.replace('-',' ')
df['Notes'] = df['Notes'].str.replace(':',' ')
df['Notes'] = df['Notes'].str.replace('#',' ')
df['Notes'] = df['Notes'].str.replace('=',' ')
df['Notes'] = df['Notes'].str.replace('?',' ')
df['Notes'] = df['Notes'].str.replace('!',' ')
df['Notes'] = df['Notes'].str.replace('fdni','fdny')
df['Date'] = df['Date'].str.replace('0:00', '')

df["Notes"] = df["Notes"].map(str.strip)
#df = df.drop_duplicates(['Address', 'Boro', 'Notes', 'Date']).reset_index(drop=True)

#prepare data for analysis, do not replace "/" cus important for acronyms
#weird spelling
df['Notes'] = df['Notes'].str.replace(' f d ',' fdny ')
df['Notes'] = df['Notes'].str.replace(' flu ',' flue ')
df['Notes'] = df['Notes'].str.replace(' fdni ',' fdny ')
df['Notes'] = df['Notes'].str.replace(' nyfd ',' fdny ')
df['Notes'] = df['Notes'].str.replace(' pd ',' nypd ')


df['Notes'] = df['Notes'].str.replace(' apt ',' apartment ')
df['Notes'] = df['Notes'].str.replace(' yr ',' year ')
df['Notes'] = df['Notes'].str.replace(' bldgs ',' buildings ')
df['Notes'] = df['Notes'].str.replace(' bldg ',' building ')
df['Notes'] = df['Notes'].str.replace(' ave ',' avenue ')
df['Notes'] = df['Notes'].str.replace(' st ',' street ')
df['Notes'] = df['Notes'].str.replace(' approx ',' approximately ')
df['Notes'] = df['Notes'].str.replace('site safety manager','ssm')

df = df.dropna()

df = df[df["Notes"] != " "]

df = df[df["Notes"] != ""]

df = df[df["Notes"] != 'nan']

#df = df.dropna()

# add injuries and fatalities and analyze data only with inujuries and fatalities greater than 0

df["Fatality and Injury"] = df["Fatality"] + df["Injury"]

df = df[df["Fatality and Injury"] > 0]

df['Date'] = pd.to_datetime(df['Date'])

# %%
#TOPIC MODELLING FOR SITE SAFETY REPORT
#SUBSET FOR DATE

start_time = '2012-09-01'
end_time = '2012-11-30'
#subset the days worked using mask
mask = (df['Date'] <= end_time) & (df['Date'] >= start_time)
df2012 = df.loc[mask]
df2012 = df2012.reset_index(drop=True)
print "length 2012:",  len(df2012), ", sum of injuries and fatalities:", df2012["Fatality and Injury"].sum()




start_time = '2013-09-01'
end_time = '2013-11-30'
#subset the days worked using mask
mask = (df['Date'] <= end_time) & (df['Date'] >= start_time)
df2013 = df.loc[mask]
df2013 = df2013.reset_index(drop=True)
print "length 2013:",  len(df2013), ", sum of injuries and fatalities:", df2013["Fatality and Injury"].sum()

start_time = '2014-09-01'
end_time = '2014-11-30'
#subset the days worked using mask
mask = (df['Date'] <= end_time) & (df['Date'] >= start_time)
df2014 = df.loc[mask]
df2014 = df2014.reset_index(drop=True)
print "length 2014:",  len(df2014), ", sum of injuries and fatalities:", df2014["Fatality and Injury"].sum()

start_time = '2015-09-01'
end_time = '2015-11-30'
#subset the days worked using mask
mask = (df['Date'] <= end_time) & (df['Date'] >= start_time)
df2015 = df.loc[mask]
df2015 = df2015.reset_index(drop=True)
print "length 2015:",  len(df2015), ", sum of injuries and fatalities:", df2015["Fatality and Injury"].sum()

start_time = '2016-09-01'
end_time = '2016-11-30'
#subset the days worked using mask
mask = (df['Date'] <= end_time) & (df['Date'] >= start_time)
df2016 = df.loc[mask]
df2016 = df2016.reset_index(drop=True)
print "length 2016:",  len(df2016), ", sum of injuries and fatalities:", df2016["Fatality and Injury"].sum()

frames = [df2012, df2013, df2014, df2015, df2016]

df = pd.concat(frames)
# Out:
# length 2012: 91 , sum of injuries and fatalities: 131.0
# length 2013: 102 , sum of injuries and fatalities: 119.0
# length 2014: 120 , sum of injuries and fatalities: 154.0
# length 2015: 200 , sum of injuries and fatalities: 249.0
# length 2016: 252 , sum of injuries and fatalities: 356.0

# %%
df
# Out:
#           Date                                              Notes  Fatality  \
# 0   2012-09-01                 oem reported car into the building       0.0
# 1   2012-09-01  fdny reported a construction worker was hit by...       0.0
# 2   2012-09-01                         aided injured on escalator       0.0
# 3   2012-09-03  fdny requested structural stability check due ...       0.0
# 4   2012-09-04  a 12 year old male while traveling down on esc...       0.0
# 5   2012-09-05  ssm reported an electrician standing on the 6f...       0.0
# 6   2012-09-05  ssm reported a construction worker suffered fr...       0.0
# 7   2012-09-06  ssm reported a construction worker knocked dow...       0.0
# 8   2012-09-06  a female  a mis hila kollnesher alledged she w...       0.0
# 9   2012-09-07  a male employee adrian henry tripped while exi...       0.0
# 10  2012-09-10          oem reported a partial roof\wall collapse       1.0
# ...

# %%
dfExport = df["Notes"]
#df.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Utility NLP\\TopicModelling\\output\\UTILITY_DATA_CLEANED.csv")
dfExport.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Topic Modelling Incidents\\Notes Topic Modelling Incidents.csv")

# %%
df.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Topic Modelling Incidents\\Topic Modelling Incidents 2.csv")

# %% [markdown]
# # Part 2: Clean Data

# %%
#text = open('S:\\Office of Risk Management\\User Folders\\Darius Mehri\\big.txt', 'r')
f = open('C:\\big2.txt.txt')

import re, collections

def words(text): return re.findall('[a-z]+', text.lower()) 

def train(features):
    model = collections.defaultdict(lambda: 1)
    for f in features:
        model[f] += 1
    return model

NWORDS = train(words(file('C:\\big2.txt.txt').read()))

alphabet = 'abcdefghijklmnopqrstuvwxyz'

def edits1(word):
   splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
   deletes    = [a + b[1:] for a, b in splits if b]
   transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
   replaces   = [a + c + b[1:] for a, b in splits for c in alphabet if b]
   inserts    = [a + c + b     for a, b in splits for c in alphabet]
   return set(deletes + transposes + replaces + inserts)

def known_edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1) if e2 in NWORDS)

def known(words): return set(w for w in words if w in NWORDS)

def correct(word):
    candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word]
    return max(candidates, key=NWORDS.get)



hey = correct('chile')
print hey
# Out:
# chile

# %%
#CLEAN and EXPORT DATA

import pandas as pd
import re, collections #for spell corrector

import time
start_time = time.time()


#df = pd.read_csv("S:\Office of Risk Management\User Folders\Darius Mehri\Utility NLP\TopicModelling\UTILITY_DATA_CLEANED.csv")

#CONVERT EVERYTHING TO STRING AND MAKE ALL LOWER CASE
df["Notes"] = df["Notes"].astype(str)
df["Notes"] = df["Notes"].map(str.lower)

#drop duplicates, strip white space first, some incidents are duplicates
#df["Address"] = df["Address"].map(str.strip)
#df["Boro"] = df["Boro"].map(str.strip)
df["Notes"] = df["Notes"].map(str.strip)
#df = df.drop_duplicates(['Address', 'Boro', 'Notes', 'Date']).reset_index(drop=True)

#prepare data for analysis, do not replace "/" cus important for acronyms
df['Notes'] = df['Notes'].str.replace('.',' ')
df['Notes'] = df['Notes'].str.replace(',',' ')
df['Notes'] = df['Notes'].str.replace('-',' ')
df['Notes'] = df['Notes'].str.replace(':',' ')
df['Notes'] = df['Notes'].str.replace('#',' ')
df['Notes'] = df['Notes'].str.replace('=',' ')
df['Notes'] = df['Notes'].str.replace('/',' ')

#weird spelling
df['Notes'] = df['Notes'].str.replace(' f d ',' fdny ')
df['Notes'] = df['Notes'].str.replace(' flu ',' flue ')
df['Notes'] = df['Notes'].str.replace(' fdni ',' fdny ')
df['Notes'] = df['Notes'].str.replace(' nyfd ',' fdny ')
df['Notes'] = df['Notes'].str.replace(' pd ',' nypd ')


df['Notes'] = df['Notes'].str.replace(' apt ',' apartment ')
df['Notes'] = df['Notes'].str.replace(' yr ',' year ')
df['Notes'] = df['Notes'].str.replace(' bldgs ',' buildings ')
df['Notes'] = df['Notes'].str.replace(' bldg ',' building ')
df['Notes'] = df['Notes'].str.replace(' ave ',' avenue ')
df['Notes'] = df['Notes'].str.replace(' st ',' street ')
df['Notes'] = df['Notes'].str.replace(' approx ',' approximately ')


#turn chain assignments off
pd.set_option('chained_assignment', None)

df = df.reset_index(drop=True)


#read in data from files of words do not want to spell check these words
dfNoDel = pd.read_csv("S:\Office of Risk Management\User Folders\Darius Mehri\Utility NLP\TopicModelling\word_dic_acronym_no_remove.csv")
dfNoDel["word"] = dfNoDel["word"].astype(str)
dfNoDel["word"] = dfNoDel["word"].map(str.strip)
#turn it into a list
dfNoDelList = []
for i in range(0, len(dfNoDel)):
    dfNoDelList.append(dfNoDel.word[i])

#read in complete english language word list to be used to check whether the corpus word exists in the list, if it
#does do not use spell corrector
dfEnglish = pd.read_csv("S:\Office of Risk Management\User Folders\Darius Mehri\Utility NLP\TopicModelling\word_list_english.csv")
dfEnglish["word"] = dfEnglish["word"].astype(str)
dfEnglish["word"] = dfEnglish["word"].map(str.strip)
#turn it into a list
dfEnglishList = []
#turn into list
for i in range(0, len(dfEnglish)):
    dfEnglishList.append(dfEnglish.word[i])

import time
start_time = time.time()

#REMOVE ALL NUMBERS



class TextClean:
    def __init__(self, df):
        self.df = df
    
    def RemoveNumbers(self):
        self.df['Notes'] = self.df['Notes'].map(lambda x: x.strip('0123456789'))

    
    def RemoveStop(self):
        stop = [line.strip() for line in open("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Utility NLP\\TopicModelling\\stopwords.txt", 'r')]
        stop = filter(None, stop)
        stop = set(stop)
        stop = list(stop)

        for i in range(0, len(self.df)):
            #split the string and put in list called dfs,  dfs = data frame speller
            dfs = self.df.Notes[i].split()
                #print dfs
                
                
            if i%1000 == 0:
                print i
                elapsed_time = time.time() - start_time
                print "Elapsed time in minutes:", elapsed_time/60, ", and hours: ", elapsed_time/3600
            
            for j in range(0, len(dfs)):
                if dfs[j] in stop:
                    dfs[j] = ""
                    
                #join the list
                dfsJoin = " ".join(dfs)
                self.df["Notes"][i] = dfsJoin
    

    def SpellCorrector(self):
        #this spell correctory was developed by peter norvig, http://norvig.com/spell-correct.html
        #The spell corrector:
        #Issues with spell corrector, "paper and work" and "pipe and work" will be changed to paperwork and pipework
        #the speller will correct pipework as paperwork, so removed pipework and paperwork from permute3
        spell_count = 0 
        for i in range(0, len(self.df)):
            #split the string and put in list called dfs,  dfs = data frame speller
            dfs = self.df.Notes[i].split()
                #print dfs
            
            
            #only corrects words not in the do not delete list and english word list, 
            #reason for english word list is do not want to replace "heater" with "theater"
            
            if i%1000 == 0:
                print i
                elapsed_time = time.time() - start_time
                print "Elapsed time in minutes:", elapsed_time/60, ", and hours: ", elapsed_time/3600
            
            for j in range(0, len(dfs)):
                
                #print dfs[j]
                #THE CONDITIONAL IN THIS SPELL CORRECTOR DOES NOT WORK, CORRECTING DFNODELLIST
                #if dfs[j] not in dfNoDelList or dfs[j] not in dfEnglishList:
                if dfs[j] not in dfEnglishList:
                    dfs[j] = correct(dfs[j])
                    
                     



                #join the list
                dfsJoin = " ".join(dfs)

                #df['Notes'] = df['Notes'].str.replace('[^\w\s]',' ')

                self.df["Notes"][i] = dfsJoin
        
        #correct spelling mistakes
        self.df['Notes'] = self.df['Notes'].str.replace(' blue ',' flue ')
        self.df['Notes'] = self.df['Notes'].str.replace(' coin ',' co in ')
        self.df['Notes'] = self.df['Notes'].str.replace(' pillage ',' spillage ')
        self.df['Notes'] = self.df['Notes'].str.replace(' theaters ',' heaters ')
        self.df['Notes'] = self.df['Notes'].str.replace('f d ',' fdny ')
        self.df['Notes'] = self.df['Notes'].str.replace('p d ',' nypd ')
        self.df['Notes'] = self.df['Notes'].str.replace(' dwyer ',' dryer ')
        #spell corrector confuses pipework with paperwork
        self.df['Notes'] = self.df['Notes'].str.replace(' paperwork ',' pipe work ')
        
        #print "sp count", spell_count

    def CodeText(self):
        self.df["Incident Type"] = ""
        self.df["Structural Stability Test"] = 0
        self.df["Worker Sick"] = 0
        self.df["Worker Fell"] = 0
        self.df["Elevator Incident"] = 0
        self.df["Escalator Incident"] = 0
        #self.df["Vehicle Hit Building"] = 0
        self.df["Worker Cut Body"] = 0
        self.df["Partial Building Collapse"] = 0
        self.df["Chest Pain"] = 0
        self.df["Falling Debris"] = 0
        #self.df["Twisted Ankle"] = 0
        self.df["Object Struck Head/Face/Body"] = 0
        self.df["Vehicle Struck Sidewalk Shed"] = 0
        self.df["Concrete Incident"] = 0
        self.df["Back and Pulled Muscle"] = 0
        self.df["Worker/Person Tripped"] = 0
        self.df["High Carbon Monoxide"] = 0
        self.df["Pedestrian Incident"] = 0
        self.df["Fire"] = 0
        self.df["Electrocuted/Burned"] = 0
        self.df["Children"] = 0
        self.df["Building Collapse"] = 0
        self.df["Explosion"] = 0
        self.df["Crane"] = 0
        self.df["Woker in Motion"] = 0
        self.df["Worker Misc Body"] = 0
        
        for i in range(0, len(self.df)):
            a = self.df["Notes"][i]
            a = a.split()
            
            
           
            
            
            
            #TWISTED ANKLE
            #if any("ankle" in s for s in a):
            #    self.df["Twisted Ankle"][i] = 1
            #    self.df["Incident Type"][i] = "Twisted Ankle"
            
            #ELEVATOR INCIDENT
            if any("elevator" in s for s in a):
                self.df["Elevator Incident"][i] = 1
                self.df["Incident Type"][i] = "Elevator Incident"
            
            #ESCALATOR INDICENT
            if any("escalator" in s for s in a):
                self.df["Escalator Incident"][i] = 1
                self.df["Incident Type"][i] = "Escalator Incident"
            
            
            #STRUCTURAL STABILITY TEST includes car or vehicle hitting building
            if any("structur" in s for s in a) and any("stabil" in s for s in a):
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if any("check" in s for s in a) and any("stabil" in s for s in a):
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            
            #CAR OR VEHICLE HIT BUILDING
            #if any("car" in s for s in a) and any("building" in s for s in a):
            if ("car " in self.df["Notes"][i] and "building" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building"
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if ("vehicle" in self.df["Notes"][i] and "building" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building"
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if ("car " in self.df["Notes"][i] and "bank" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building"
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if ("vehicle" in self.df["Notes"][i] and "bank" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building"
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if ("car " in self.df["Notes"][i] and "wall" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building"
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if ("vehicle" in self.df["Notes"][i] and "wall" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building"
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            #if any("truck" in s for s in a) and any("building" in s for s in a):
            if (" truck " in self.df["Notes"][i] and "building" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building"
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if ("automobile" in self.df["Notes"][i] and "building" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building" 
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if ("car " in self.df["Notes"][i] and "premise" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building" 
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
            if ("vehicle" in self.df["Notes"][i] and "premise" in self.df["Notes"][i]):
                #self.df["Vehicle Hit Building"][i] = 1
                #self.df["Incident Type"][i] = "Vehicle Hit Building" 
                self.df["Structural Stability Test"][i] = 1
                self.df["Incident Type"][i] = "Structural Stability"
                
            #VEHICLE STRUCK SIDEWALK SHED, and includes scaffolds
            if (("car" in self.df["Notes"][i] or "truck" in self.df["Notes"][i]) and "shed" in self.df["Notes"][i]):
                self.df["Vehicle Struck Sidewalk Shed"][i] = 1
                self.df["Incident Type"][i] = "Vehicle Struck Sidewalk Shed"
            if (("vehicle" in self.df["Notes"][i] or "taxi" in self.df["Notes"][i]) and "shed" in self.df["Notes"][i]):
                self.df["Vehicle Struck Sidewalk Shed"][i] = 1
                self.df["Incident Type"][i] = "Vehicle Struck Sidewalk Shed"
            if (("car" in self.df["Notes"][i] or "truck" in self.df["Notes"][i]) and "scaffold" in self.df["Notes"][i]):
                self.df["Vehicle Struck Sidewalk Shed"][i] = 1
                self.df["Incident Type"][i] = "Vehicle Struck Sidewalk Shed"
            if (("vehicle" in self.df["Notes"][i] or "taxi" in self.df["Notes"][i]) and "scaffold" in self.df["Notes"][i]):
                self.df["Vehicle Struck Sidewalk Shed"][i] = 1
                self.df["Incident Type"][i] = "Vehicle Struck Sidewalk Shed"
                
            #WORKER CUT BODY PART, FINGER/HAND
            if (" cut" in self.df["Notes"][i] and "finger" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if ("severed" in self.df["Notes"][i] and "finger" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "thumb" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and " hand" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "knee" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and " arm" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "pinky" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "forearm" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "leg" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "elbow" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "cheek" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "wrist" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if (" cut" in self.df["Notes"][i] and "nose" in self.df["Notes"][i]):
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            if "lacerat" in self.df["Notes"][i]:
                self.df["Worker Cut Body"][i] = 1
                self.df["Incident Type"][i] = "Worker Cut Body"
            
            
            #PARTIAL BUILDING COLLAPSE, includes scaffold, catwalk, stairs, etc
            if ("ceiling" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("wall" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("stair" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("catwalk" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("scaffold" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("partial" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("floor" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("porch" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("gate" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
            if ("fence" in self.df["Notes"][i] and "collaps" in self.df["Notes"][i]):
                self.df["Partial Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Partial Building Collapse"
                
                
            #BUILDING COLLAPSE
            if ((self.df["Partial Building Collapse"][i] == 0) and ("collaps" in self.df["Notes"][i] and " building " in self.df["Notes"][i])):
                self.df["Building Collapse"][i] = 1
                self.df["Incident Type"][i] = "Building Collapse" 
            
            
            #WORKER HAVING CHEST PAINS, HEART ATTACK
            if (" chest " in self.df["Notes"][i] and "pain" in self.df["Notes"][i]):
                self.df["Chest Pain"][i] = 1
                self.df["Incident Type"][i] = "Chest Pain"
            if ("heart" in self.df["Notes"][i] and "attack" in self.df["Notes"][i]):
                self.df["Chest Pain"][i] = 1
                self.df["Incident Type"][i] = "Chest Pain"
            if ("heart" in self.df["Notes"][i] and "condition" in self.df["Notes"][i]):
                self.df["Chest Pain"][i] = 1
                self.df["Incident Type"][i] = "Chest Pain"
            if ("heart" in self.df["Notes"][i] and "pain" in self.df["Notes"][i]):
                self.df["Chest Pain"][i] = 1
                self.df["Incident Type"][i] = "Chest Pain"
            if ("cardiac" in self.df["Notes"][i] and "arrest" in self.df["Notes"][i]):
                self.df["Chest Pain"][i] = 1
                self.df["Incident Type"][i] = "Chest Pain"
            if ("cardiac" in self.df["Notes"][i] and "pain" in self.df["Notes"][i]):
                self.df["Chest Pain"][i] = 1
                self.df["Incident Type"][i] = "Chest Pain"
           
            
            #WORKER FELL
            b = ['worker fell','workers fell', 'man fell', 'men fell','male fell', 'female fell', 'woman fell', 'women fell', 'worker fall', 'person fell', 'worker falling', 'workers falling'] 
            for count in b:
                if count in self.df["Notes"][i]:
                    self.df["Worker Fell"][i] = 1
                    self.df["Incident Type"][i] = "Worker(s) Fell"
            
            
            #FALLING DEBRIS
            if ("debris" in self.df["Notes"][i] and "fall" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"  
            if ("debris" in self.df["Notes"][i] and "fell" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if ("brick" in self.df["Notes"][i] and "fall" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"  
            if ("brick" in self.df["Notes"][i] and "fell" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if ("fence" in self.df["Notes"][i] and "fall" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"  
            if ("fence" in self.df["Notes"][i] and "fell" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if ("masonry" in self.df["Notes"][i] and "fall" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if ("masonry" in self.df["Notes"][i] and "fell" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if ("metal" in self.df["Notes"][i] and "fall" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if ("metal" in self.df["Notes"][i] and "fell" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if ("material" in self.df["Notes"][i] and "fall" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if ("mason" in self.df["Notes"][i] and "fell" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 1
                self.df["Incident Type"][i] = "Falling Debris"
            if "fell" in self.df["Notes"][i]:
                if "scaffold" in self.df["Notes"][i]:
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if "ceiling" in self.df["Notes"][i]:
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("beam" in self.df["Notes"][i] or "lumber" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("fire escape" in self.df["Notes"][i] or "sign" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("glass" in self.df["Notes"][i] or "washer" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("fork lift" in self.df["Notes"][i] or "motor" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("wood" in self.df["Notes"][i] or "motor" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("sheetrock" in self.df["Notes"][i] or "equipment" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("air conditioner" in self.df["Notes"][i] or "end cap" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("awning" in self.df["Notes"][i] or "shoring" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("garbage" in self.df["Notes"][i] or "plaster" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("shed" in self.df["Notes"][i] or "window frame" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("slag" in self.df["Notes"][i] or "sheet rock" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("plywood" in self.df["Notes"][i] or "container" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("pipe" in self.df["Notes"][i] or "machine" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"
                if ("counter weight" in self.df["Notes"][i] or "window" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"   
                if ("hammer" in self.df["Notes"][i] or "window" in self.df["Notes"][i]):
                    self.df["Falling Debris"][i] = 1
                    self.df["Incident Type"][i] = "Falling Debris"  
                    
            #correct for "worker fell" compared to "object fell" on worker
            if "worker fell" in self.df["Notes"][i]:
                self.df["Falling Debris"][i] = 0
                self.df["Worker Fell"][i] = 1
                self.df["Incident Type"][i] = "Worker(s) Fell"
            if "workers fell" in self.df["Notes"][i]:
                self.df["Falling Debris"][i] = 0
                self.df["Worker Fell"][i] = 1
                self.df["Incident Type"][i] = "Worker(s) Fell"
            if "person fell" in self.df["Notes"][i]:
                self.df["Falling Debris"][i] = 0
                self.df["Worker Fell"][i] = 1
                self.df["Incident Type"][i] = "Worker(s) Fell"
            if ("man fell" in self.df["Notes"][i] or "male fell" in self.df["Notes"][i]):
                self.df["Falling Debris"][i] = 0
                self.df["Worker Fell"][i] = 1
                self.df["Incident Type"][i] = "Worker(s) Fell"
            if "men fell" in self.df["Notes"][i]:
                self.df["Falling Debris"][i] = 0
                self.df["Worker Fell"][i] = 1
                self.df["Incident Type"][i] = "Worker(s) Fell"
            #use word position to exclude "worker xjh alkjd fell"
            if ("worker" in self.df["Notes"][i] and "fell" in self.df["Notes"][i]):
                if self.df["Notes"][i].find("worker") < self.df["Notes"][i].find("fell"):
                    self.df["Falling Debris"][i] = 0
                    self.df["Worker Fell"][i] = 1
                    self.df["Incident Type"][i] = "Worker(s) Fell"
       
            
            #HEAD/FACE INJURY, object hit worker in the face, head, body when he/she was working
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "face" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "eye" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "nose" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "chest" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "foot" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "arm" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "finger" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "head" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "leg" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "shoulder" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "worker" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "steel beam" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            if (("struck" in self.df["Notes"][i] or "hit" in self.df["Notes"][i]) and "steel beam" in self.df["Notes"][i]):
                self.df["Object Struck Head/Face/Body"][i] = 1
                self.df["Incident Type"][i] = "Object Struck Head/Face/Body"
            
            #CONCERTE INCIDENTS, injuries caused by concerte pouring, pump,  cutting, etc
            if any("concrete" in s for s in a):
                self.df["Concrete Incident"][i] = 1
                self.df["Incident Type"][i] = "Concrete Incident"
            
            #WORKER SICK
            #if text contains any of these words
            b = ['dizz','epilept', 'sluggish', ' ill ', ' faint', 'not feel', 'seizur', ' stroke ', \
                 'sick', 'heat exhaus', "shortness of brea", "felt light head", 'asthma', 'blood pressure', 'stomach', 'abdom'] 
            for count in b:
                if count in self.df["Notes"][i]:
                    self.df["Worker Sick"][i] = 1
                    self.df["Incident Type"][i] = "Worker Sick"
                    
            #BACK INJURY AND MUSCLE PULL 
            if ("pull" in self.df["Notes"][i] and "muscle" in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle"  
            if ("pull" in self.df["Notes"][i] and " back " in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle"
            if ("spasm" in self.df["Notes"][i] and "muscle" in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle"
            #some issues with this, codes back injury even if  "be back","came back",  "kicked back", "bounced back" in text
            if ("strain" in self.df["Notes"][i] and " back " in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle"
            if ("twist" in self.df["Notes"][i] and " back " in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle" 
            if ("hurt" in self.df["Notes"][i] and " back " in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle"
            if ("injur" in self.df["Notes"][i] and " back " in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle" 
            if ("lock" in self.df["Notes"][i] and " back " in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle" 
            if ("spasm" in self.df["Notes"][i] and " back " in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle"
            if ("pain" in self.df["Notes"][i] and " back " in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 1
                self.df["Incident Type"][i] = "Back and Pulled Muscle" 
            
            #correct for "bounced back", "kicked back", categorized as back injury 
            if ("bounced back" in self.df["Notes"][i] or "kicked back" in self.df["Notes"][i]):
                self.df["Back and Pulled Muscle"][i] = 0
                self.df["Incident Type"][i] = ""
            
            #WORKER TRIPPED
            if any("tripped" in s for s in a):
                self.df["Worker/Person Tripped"][i] = 1
                self.df["Incident Type"][i] = "Worker/Person Tripped"
            if any("trip" in s for s in a):
                self.df["Worker/Person Tripped"][i] = 1
                self.df["Incident Type"][i] = "Worker/Person Tripped"
            if any("slipped" in s for s in a):
                self.df["Worker/Person Tripped"][i] = 1
                self.df["Incident Type"][i] = "Worker/Person Tripped"
           
        
            #MISCELLENOUS BODY INJURY, workers working injured themselves
            if self.df["Incident Type"][i] == "":
                b = ["leg", "knee", "eye", "hand", "arm", "head", "finger", "foot", "bleeding", "nose", "pinky", "thumb", "forearm"  "stepped on nail", "stepped on a nail", "shin", "shoulder", "ear", "heal", "face", "elbow"]
                for count in b:
                    if count in self.df["Notes"][i]:
                        self.df["Worker Misc Body"][i] = 1
                        self.df["Incident Type"][i] = "Worker Misc Body"
            
                
            #HIGH CARBON MONIXIDE
            if "carbon mono" in self.df["Notes"][i]:
                self.df["High Carbon Monoxide"][i] = 1
                self.df["Incident Type"][i] = "High Carbon Monoxide"
            if " co reading" in self.df["Notes"][i]:
                self.df["High Carbon Monoxide"][i] = 1
                self.df["Incident Type"][i] = "High Carbon Monoxide"
            
            #PEDESTRIAN INCIDENT
            if "pedestr" in self.df["Notes"][i]:
                self.df["Pedestrian Incident"][i] = 1
                self.df["Incident Type"][i] = "Pedestrian Incident"
                
            #FIRE
            if "alarm fire" in self.df["Notes"][i]:
                self.df["Fire"][i] = 1
                self.df["Incident Type"][i] = "Fire"
                
            #ELECTROCUTED OR BURNED, WORKER PERSON
            if "burn" in self.df["Notes"][i]:
                self.df["Electrocuted/Burned"][i] = 1
                self.df["Incident Type"][i] = "Electrocuted/Burned"
            if "electroc" in self.df["Notes"][i]:
                self.df["Electrocuted/Burned"][i] = 1
                self.df["Incident Type"][i] = "Electrocuted/Burned"
            if " shock" in self.df["Notes"][i]:
                self.df["Electrocuted/Burned"][i] = 1
                self.df["Incident Type"][i] = "Electrocuted/Burned"
          
            
            #CHILDREN INCIDENTS
            if "child" in self.df["Notes"][i]:
                self.df["Children"][i] = 1
                self.df["Incident Type"][i] = "Children"
            if "boy" in self.df["Notes"][i]:
                self.df["Children"][i] = 1
                self.df["Incident Type"][i] = "Children"
            if "girl" in self.df["Notes"][i]:
                self.df["Children"][i] = 1
                self.df["Incident Type"][i] = "Children"
                
            
            #BUILDING EXPLOSION
            if "explosion" in self.df["Notes"][i]:
                self.df["Explosion"][i] = 1
                self.df["Incident Type"][i] = "Explosion" 
             
            #CRANE INCIDENTS
            if "crane" in self.df["Notes"][i]:
                self.df["Crane"][i] = 1
                self.df["Incident Type"][i] = "Crane" 
            
            #WORKER IN MOTION, loading, unloading, lifting, moving, installing, climbing
            if "loading" in self.df["Notes"][i]:
                self.df["Woker in Motion"][i] = 1
                self.df["Incident Type"][i] = "Woker in Motion" 
            if ("worker" in self.df["Notes"][i] and "moving" in self.df["Notes"][i]):
                self.df["Woker in Motion"][i] = 1
                self.df["Incident Type"][i] = "Woker in Motion"
            if "removing" in self.df["Notes"][i]:
                self.df["Woker in Motion"][i] = 1
                self.df["Incident Type"][i] = "Woker in Motion"
            if "lifting" in self.df["Notes"][i]:
                self.df["Woker in Motion"][i] = 1
                self.df["Incident Type"][i] = "Woker in Motion"
            if "handling" in self.df["Notes"][i]:
                self.df["Woker in Motion"][i] = 1
                self.df["Incident Type"][i] = "Woker in Motion"  
            if "installing" in self.df["Notes"][i]:
                self.df["Woker in Motion"][i] = 1
                self.df["Incident Type"][i] = "Woker in Motion"   
            if "climbing" in self.df["Notes"][i]:
                self.df["Woker in Motion"][i] = 1
                self.df["Incident Type"][i] = "Woker in Motion"
    
    #def RenameColumns(self):
        
    
    def ExportData(self):
        #export only with injuries
        self.df.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Topic Modelling Incidents\\Topic Modelling Incidents 9_1_15 to 11_30_16 CLEANED injury.csv")
   
    
    def PrintProgress(self):
        print "Length of dataset:", len(self.df)
        dfCB = self.df[self.df["Incident Type"] != ""]
        print "Length of dataset with incidents coded: ", len(dfCB)
        print
        print "Percent coded accurately: ", round(len(dfCB)/float(len(self.df)), 2)
        
    #def HeatMap(self):
    #    for i in range(2007, 2017):
    #        dfhm = self.df[self.df["Incident Type"] != ""]

    
data = TextClean(df)

print
print "Running spell corrector ..."
data.SpellCorrector()
print
print "Coding Text ..."
data.CodeText()
print
print "Exporting data ..."
data.ExportData()
print
print "Calculating progress"
data.PrintProgress()

#df.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Utility NLP\\TopicModelling\\output\\UTILITY_DATA_CLEANED.csv")

#dfExport = df["Notes"]
#df.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Utility NLP\\TopicModelling\\output\\UTILITY_DATA_CLEANED.csv")
#dfExport.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Topic Modelling Incidents\\Notes Topic Modelling Incidents.csv")

print
print "DONE WITH TEXT CLEANING AND CODING"
# Out:
# Running spell corrector ...
# 0
# Elapsed time in minutes: 0.0107166647911 , and hours:  0.000178611079852
#
# Coding Text ...
#
# Exporting data ...
#
# Calculating progress
# Length of dataset: 765
# Length of dataset with incidents coded:  715
#
# Percent coded accurately:  0.93
#
# DONE WITH TEXT CLEANING AND CODING

# %%
df.dtypes
# Out:
# Date                            datetime64[ns]
# Notes                                   object
# Fatality                               float64
# Injury                                 float64
# Fatality and Injury                    float64
# Incident Type                           object
# Structural Stability Test                int64
# Worker Sick                              int64
# Worker Fell                              int64
# Elevator Incident                        int64
# Escalator Incident                       int64
# Worker Cut Body                          int64
# Partial Building Collapse                int64
# Chest Pain                               int64
# Falling Debris                           int64
# Object Struck Head/Face/Body             int64
# Vehicle Struck Sidewalk Shed             int64
# Concrete Incident                        int64
# Back and Pulled Muscle                   int64
# Worker/Person Tripped                    int64
# ...

# %%
df.head(3)
# Out:
#         Date                                              Notes  Fatality  \
# 0 2012-09-01                 oem reported car into the building       0.0
# 1 2012-09-01  fdny reported a construction worker was hit by...       0.0
# 2 2012-09-01                         aided injured on escalator       0.0
#
#    Injury  Fatality and Injury                 Incident Type  \
# 0     1.0                  1.0          Structural Stability
# 1     1.0                  1.0  Object Struck Head/Face/Body
# 2     1.0                  1.0            Escalator Incident
#
#    Structural Stability Test  Worker Sick  Worker Fell  Elevator Incident  \
# 0                          1            0            0                  0
# 1                          0            0            1                  0
# 2                          0            0            0                  0
#
#          ...         High Carbon Monoxide  Pedestrian Incident  Fire  \
# ...

# %%
df.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Site Safety Report\\Topic Modelling.csv")

# %%
df["Year"] = ""

for i in (0, len(df)):
    year = df["Date"][i].year

# %%
for i in range(2007, 2017):
    
    dfCB = self.df[self.df["Incident Type"] != ""]

# %%
df["Date"][0].year
# Out:
# 2007

# %%
#rename topics
df = df.rename(columns={'Back and Pulled Muscle': 'Worker Back and Pulled Muscle'})
df = df.rename(columns={'Chest Pain': 'Worker Chest Pain'})
df = df.rename(columns={'Object Struck Head/Face/Body': 'Worker Object Struck Head/Face/Body'})
df = df.rename(columns={'Electrocuted/Burned': 'Worker Electrocuted/Burned'})

# %%
print "length with blanks in incident type", len(df)
df = df[df["Incident Type"] != ""]
df = df.reset_index(drop=True)
print "current length", len(df)
# Out:
# length with blanks in incident type 4839
# current length 4475

# %%
df.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Topic Modelling Incidents\\Topic Modelling Incidents 4 CLEANED.csv")

# %% [markdown]
# # Part 3: Analyze Results

# %%
import pandas as pd
import numpy as np

dr = pd.read_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Topic Modelling Incidents\\TM Results 2.csv")

#dr.dtypes

#multiply all floats by 100 to convert into percent
dr[dr.select_dtypes(include=['float']).columns] *= 100

dr = dr.round(2)

dr = dr.rename(columns={'Topic14': 'Structural Stability Check Request'})

dr = dr.rename(columns={'Topic5': 'SSM Worker Injured While Working 1'})

dr = dr.rename(columns={'Topic8': 'SSM Worker Feeling Sick 1'})
dr = dr.rename(columns={'Topic16': 'Worker Fell From Scaffold/Ladder 1'})
dr = dr.rename(columns={'Topic4': 'Worker Fell From Scaffold/Ladder 2'})
dr = dr.rename(columns={'Topic35': 'SSM Miscellaneous Injury 2'})
dr = dr.rename(columns={'Topic21': 'Worker Fell'})
dr = dr.rename(columns={'Topic30': 'FDNY Inspection Due to Injury 1'})
dr = dr.rename(columns={'Topic26': 'OEM Damage to Building/Misc Incident'})
dr = dr.rename(columns={'Topic49': 'Elevator Door Incident'})
dr = dr.rename(columns={'Topic44': 'Vehicle Hit Building'})
dr = dr.rename(columns={'Topic28': 'Escalator Incident 1'})
dr = dr.rename(columns={'Topic38': 'Escalator Incident 2'})
dr = dr.rename(columns={'Topic31': 'SSM Worker Cut Finger'})
dr = dr.rename(columns={'Topic11': 'FDNY Inspection Due to Injury 2'})
dr = dr.rename(columns={'Topic15': 'FDNY Wall/Ceiling Collapse'})
dr = dr.rename(columns={'Topic20': 'SSM Chest Pain'})
dr = dr.rename(columns={'Topic18': 'Worker Sick/Injured Sent Home/Doctor'})
dr = dr.rename(columns={'Topic3': 'FDNY Inspection Falling Debris/Worker'})
dr = dr.rename(columns={'Topic29': 'Escalator Incident 3'})
dr = dr.rename(columns={'Topic45': 'Worker Twisted Ankle'})
dr = dr.rename(columns={'Topic12': 'SSM Miscellaneous Injury 3'})
dr = dr.rename(columns={'Topic40': 'SSM Miscellaneous Injury 4'})
dr = dr.rename(columns={'Topic19': 'Worker Fell Through Floor'})
dr = dr.rename(columns={'Topic36': 'Finger/Hand Injury'})
dr = dr.rename(columns={'Topic50': 'Escalator Incident 4'})
dr = dr.rename(columns={'Topic37': 'Elevator Incident 1'})
dr = dr.rename(columns={'Topic6': 'SSM Worker Received Laceration Injury'})
dr = dr.rename(columns={'Topic25': 'SSM Worker Feeling Sick 2'})

dr = dr.rename(columns={'Topic42': 'SSM Moving Material Truck'})

dr = dr.rename(columns={'Topic47': 'SSM Object Hit Worker Face'})
dr = dr.rename(columns={'Topic48': 'SSM Miscellaneous Injury 5'})
dr = dr.rename(columns={'Topic1': 'Vehicle Hit Sidewalk Shed'})
dr = dr.rename(columns={'Topic7': 'Concrete Incident'})
dr = dr.rename(columns={'Topic39': 'Elevator Incident 2'})
dr = dr.rename(columns={'Topic46': 'SSM Back Injury'})

dr = dr.rename(columns={'Topic41': 'Injury on Street'})


dr = dr.rename(columns={'Topic34': 'SSM Worker Tripped'})
dr = dr.rename(columns={'Topic24': 'Miscellaneous Injury 1'})
dr = dr.rename(columns={'Topic43': 'High Carbon Monoxide'})
dr = dr.rename(columns={'Topic2': 'Pedestrian Hit Building Facade Material'})
dr = dr.rename(columns={'Topic17': 'FDNY Vehicle Hit Building'})
dr = dr.rename(columns={'Topic33': 'SSM Worker Injured While Working 2'})
dr = dr.rename(columns={'Topic23': 'Miscellaneous Injury 2'})
dr = dr.rename(columns={'Topic32': 'Child Escalator Incident'})
dr = dr.rename(columns={'Topic13': 'SSM Eye Injury'})
dr = dr.rename(columns={'Topic9': 'SSM Miscellaneous Injury 6'})
dr = dr.rename(columns={'Topic22': 'SSM Miscellaneous Injury 7'})
dr = dr.rename(columns={'Topic27': 'Escalator Incident 5'})
dr = dr.rename(columns={'Topic10': 'SSM Miscellaneous Injury 8'})

# %%
dr
# Out:
#             Date           Boro  \
# 0     2007-01-02          Bronx
# 1     2007-01-06      Manhattan
# 2     2007-01-08      Manhattan
# 3     2007-01-09         Queens
# 4     2007-01-09      Manhattan
# 5     2007-01-12      Manhattan
# 6     2007-01-16      Manhattan
# 7     2007-01-17      Manhattan
# 8     2007-01-18         Queens
# 9     2007-01-19      Manhattan
# 10    2007-01-19      Manhattan
# 11    2007-01-20      Manhattan
# 12    2007-01-21      Manhattan
# 13    2007-01-22      Manhattan
# 14    2007-01-23       Brooklyn
# 15    2007-01-23       Brooklyn
# 16    2007-01-23      Manhattan
# 17    2007-01-25          Bronx
# 18    2007-01-27       Brooklyn
# 19    2007-01-28      Manhattan
# 20    2007-01-29       Brooklyn
# 21    2007-02-01      Manhattan
# 22    2007-02-01      Manhattan
# 23    2007-02-02      Manhattan
# 24    2007-02-02      Manhattan
# 25    2007-02-04         Queens
# 26    2007-02-05      Manhattan
# 27    2007-02-08      Manhattan
# ...

# %%
#Combine topics
dr["SSM Worker Injured While Working"] = dr["SSM Worker Injured While Working 1"] +  dr["SSM Worker Injured While Working 2"]
dr = dr.drop('SSM Worker Injured While Working 1', 1)
dr = dr.drop('SSM Worker Injured While Working 2', 1)

dr["SSM Worker Feeling Sick"] = dr["SSM Worker Feeling Sick 1"] + dr["SSM Worker Feeling Sick 2"]
dr = dr.drop('SSM Worker Feeling Sick 1', 1)
dr = dr.drop('SSM Worker Feeling Sick 2', 1)

dr["Worker Fell Scaffold/Ladder"] = dr["Worker Fell From Scaffold/Ladder 1"] + dr["Worker Fell From Scaffold/Ladder 2"]
dr = dr.drop('Worker Fell From Scaffold/Ladder 1', 1)
dr = dr.drop('Worker Fell From Scaffold/Ladder 2', 1)

dr["SSM Miscellaneous Injury"] =  dr["SSM Miscellaneous Injury 2"] + dr["SSM Miscellaneous Injury 3"] + \
                                 dr["SSM Miscellaneous Injury 4"] + dr["SSM Miscellaneous Injury 5"] + dr["SSM Miscellaneous Injury 6"] + \
                                 dr["SSM Miscellaneous Injury 7"] + dr["SSM Miscellaneous Injury 8"]
        
dr = dr.drop('SSM Miscellaneous Injury 2', 1)
dr = dr.drop('SSM Miscellaneous Injury 3', 1)
dr = dr.drop('SSM Miscellaneous Injury 4', 1)
dr = dr.drop('SSM Miscellaneous Injury 5', 1)
dr = dr.drop('SSM Miscellaneous Injury 6', 1)
dr = dr.drop('SSM Miscellaneous Injury 7', 1)
dr = dr.drop('SSM Miscellaneous Injury 8', 1)

dr["Elevator Incident"] = dr['Elevator Door Incident'] + dr["Elevator Incident 1"] + dr["Elevator Incident 2"]
dr = dr.drop('Elevator Door Incident', 1)
dr = dr.drop('Elevator Incident 1', 1)
dr = dr.drop('Elevator Incident 2', 1)

dr["Escalator Incident"] = dr["Escalator Incident 1"] + dr["Escalator Incident 2"] + dr["Escalator Incident 3"] + \
                           dr["Escalator Incident 4"] + dr["Escalator Incident 5"]
    
dr = dr.drop('Escalator Incident 1', 1)
dr = dr.drop('Escalator Incident 2', 1)
dr = dr.drop('Escalator Incident 3', 1)
dr = dr.drop('Escalator Incident 4', 1)
dr = dr.drop('Escalator Incident 5', 1)

dr["FDNY Inspection Due to Injury"] = dr["FDNY Inspection Due to Injury 1"] + dr["FDNY Inspection Due to Injury 2"]
dr = dr.drop('FDNY Inspection Due to Injury 1', 1)
dr = dr.drop('FDNY Inspection Due to Injury 2', 1)

dr["Miscellaneous Injury"] = dr["Miscellaneous Injury 1"] + dr["Miscellaneous Injury 2"]
dr = dr.drop('Miscellaneous Injury 1', 1)
dr = dr.drop('Miscellaneous Injury 2', 1)

dr["Worker Fell 2"] = dr["Worker Fell"] + dr["Worker Fell Scaffold/Ladder"] + dr["Worker Fell Through Floor"]
dr = dr.drop('Worker Fell', 1)
dr = dr.drop('Worker Fell Scaffold/Ladder', 1)
dr = dr.drop('Worker Fell Through Floor', 1)

dr = dr.rename(columns={'Worker Fell 2': 'Worker Fell'})

# %%
dr
# Out:
#             Date           Boro  \
# 0     2007-01-02          Bronx
# 1     2007-01-06      Manhattan
# 2     2007-01-08      Manhattan
# 3     2007-01-09         Queens
# 4     2007-01-09      Manhattan
# 5     2007-01-12      Manhattan
# 6     2007-01-16      Manhattan
# 7     2007-01-17      Manhattan
# 8     2007-01-18         Queens
# 9     2007-01-19      Manhattan
# 10    2007-01-19      Manhattan
# 11    2007-01-20      Manhattan
# 12    2007-01-21      Manhattan
# 13    2007-01-22      Manhattan
# 14    2007-01-23       Brooklyn
# 15    2007-01-23       Brooklyn
# 16    2007-01-23      Manhattan
# 17    2007-01-25          Bronx
# 18    2007-01-27       Brooklyn
# 19    2007-01-28      Manhattan
# 20    2007-01-29       Brooklyn
# 21    2007-02-01      Manhattan
# 22    2007-02-01      Manhattan
# 23    2007-02-02      Manhattan
# 24    2007-02-02      Manhattan
# 25    2007-02-04         Queens
# 26    2007-02-05      Manhattan
# 27    2007-02-08      Manhattan
# ...

# %%
dr.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Topic Modelling Incidents\\TM Results Tableau 2.csv")

# %% [markdown]
# # RECODE USING KEY WORDS FROM TOPIC MODELS

# %%
a = "fdny requested structural stability check due to th alarm fire"
a = a.split()

print a


if any("structur" in s for s in a) and any("stabil" in s for s in a):
    print "in here"
else:
    print "not in here"

#if b in a:
#    print "in here"
# Out:
# ['fdny', 'requested', 'structural', 'stability', 'check', 'due', 'to', 'th', 'alarm', 'fire']
# not in here

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
s = "ssm reported a construction worker while lowering a suspended scaffold fell approximately a ft ambulance was called he was taken to the hospital"

print s.find("worker")
print s.find("fell")
# Out:
# 28
# 71
